# %% [markdown]
# 1) Consult the following Bayesian network, and find the probability it ascribes to the event GoodDiet ^ Scurvy ^ Tired ^ ¬JointPain.  Then find the probability of GoodDiet ^ ¬Scurvy ^ Tired ^ ¬JointPain, and finally, use these two probabilities to compute P(Scurvy | GoodDiet ^ Tired ^ ¬JointPain).
# ![Screen Shot 2022-07-13 at 1.48.16 PM.png](data:image/png;base64,...)

# %%
# TODO probability calc
GoodDiet ^ Scurvy ^ Tired ^ ¬JointPain = p(GoodDiet) *

# %% [markdown]
# 2) Compute the probabilities of two "worlds" in which ¬GoodDiet holds, P(¬GoodDiet ^ Scurvy ^ Tired ^ ¬JointPain) and P(¬GoodDiet ^ ¬Scurvy ^ Tired ^ ¬JointPain).  Then use these probabilities and your work from the previous problem to calculate P(Scurvy | Tired ^ ¬JointPain), that is, the same conditional probability as in problem (1) but without knowing the value of GoodDiet.  (Hint:  Sum the two Scurvy outcomes, then divide by the sum over all 4 possible worlds.)

# %%
# TODO probability calc

# %% [markdown]
# # Decision Tree Basics

# %% [markdown]
# 3) A decision tree classifier that predicts whether a book will be a bestseller is evaluating the goodness of the feature Nonfiction.  Exactly half of the books in the training data are Nonfiction.  Of the Nonfiction books, 1/100 are bestsellers.  Of the non-Nonfiction books, 1/10 are bestsellers.  Evaluate the expected entropy of this feature.

# %%
# TODO entropy calc

# %% [markdown]
# 4)  A decision tree is being built to classify whether cars are worth buying to resell (WorthBuying).  The two binary features being evaluated are Recent (if the car is from the past 5 years) and Cheap (if the car is being sold for under its blue book value).  There are 1500 datapoints being used in all.  Among the 500 Recent cars, 400 were considered WorthBuying.  Among the 1000 not-Recent cars, 200 were considered WorthBuying.  Among the 800 Cheap cars, 500 were considered WorthBuying.  Among the 700 not-Cheap cars, just 100 were considered WorthBuying.  Which feature, Recent or Cheap, is the better feature to split on?

# %%
# TODO entropy calc

# %% [markdown]
# **TODO which feature is better to split on?**

# %% [markdown]
# 5) What is overfitting, and how can you tell it is happening?

# %% [markdown]
# **TODO**

# %% [markdown]
# 6) Why do we separate training data from validation data from test data?

# %% [markdown]
# **TODO**
